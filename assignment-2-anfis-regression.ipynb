# %%
"Assignment 2 - ANFIS for regression problem"

import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,accuracy_score,classification_report
import skfuzzy as fuzz
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import pandas
import sys

# %%
"Import datasets for both problems"

#binary classification dataset
data_b = datasets.fetch_openml("diabetes",version=1, as_frame=True)

#regression dataset
data_r = datasets.load_diabetes(as_frame=True)

#user input to select the dataset/task
task = input("Choose binary (b) or regression (r) dataset: ")

if task == "b":
    data = data_b
    y = data.target.map({'tested_negative': 0, 'tested_positive': 1}).values #convert the text data to binary
elif task == "r":
    data = data_r
    y = data.target.values
else:
    sys.exit()

X = data.data.values

#verifying the data
print(X.shape)
#print(X)
#print(y.shape)
#print(y)
# Out:
# (442, 10)

# %%
"Train test spliting"
#choosing the percentage of data used for testing 
#and spliting the train and test data into different variables

test_size=0.2
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
"Standardizing the features"
#each feature will have mean=0 and std=1
#improves numerical stability and distance-based methods

scaler=StandardScaler()
Xtr = scaler.fit_transform(Xtr)
Xte = scaler.transform(Xte)

# %%
"Fuzzy C-Means (FCM) clustering"

#defining the number of clusters
n_clusters = 2
#defining the fuzzification coefficient 
m = 2

#concatenate target for clustering (only for regression problems)
Xexp = np.concatenate([Xtr, ytr.reshape(-1, 1)], axis=1)

#transpose data for skfuzzy (expects features x samples)
Xexp_T = Xexp.T 

#fuzzy C-means clustering
centers, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    Xexp_T, n_clusters, m=m, error=0.005, maxiter=1000, init=None,
)

print("Cluster centers shape:", centers.shape)
# Out:
# Cluster centers shape: (2, 11)

# %%
"Compute sigma (spread) for each cluster"

sigmas = []
for j in range(n_clusters):
    #membership weights for cluster j, raised to m
    u_j = u[j, :] ** m
    #weighted variance for each feature
    var_j = np.average((Xexp - centers[j])**2, axis=0, weights=u_j)
    sigma_j = np.sqrt(var_j)
    sigmas.append(sigma_j)
sigmas=np.array(sigmas)

#the sigmas define the Gaussian width for each input feature
#they control how strongly each sample activates a fuzzy rule

# %%
"Hard clustering from fuzzy membership"

cluster_labels = np.argmax(u, axis=0)
print("Fuzzy partition coefficient (FPC):", fpc)

#plot first two features with fuzzy membership
plt.figure(figsize=(8,6))
for j in range(n_clusters):
    plt.scatter(
        Xexp[cluster_labels == j, 0],             #feature 1
        Xexp[cluster_labels == j, 1],             #feature 2
        alpha=u[j, :],          #transparency ~ membership
        label=f'Cluster {j}'
    )

plt.title("Fuzzy C-Means Clustering (with membership degree)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
# Out:
# Fuzzy partition coefficient (FPC): 0.8556216992475427

# %%
"Plot first two features with cluster assignments"
plt.figure(figsize=(8,6))
for j in range(n_clusters):
    plt.scatter(
        Xexp[cluster_labels == j, 0],
        Xexp[cluster_labels == j, 1],
        label=f'Cluster {j}'
    )

plt.title("Fuzzy C-Means Clustering (CRISPEN)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %%
"Gaussian formula"
def gaussian(x, mu, sigma):
    return np.exp(-0.5 * ((x - mu)/sigma)**2)

lin=np.linspace(-2, 4, 500)
plt.figure(figsize=(8,6))

y_aux = []
feature = 0 #feature index for visualization
for j in range(n_clusters):
    #compute Gaussian curves
    y_aux.append(gaussian(lin, centers[j,feature], sigmas[j,feature]))
    #plot
    plt.plot(lin, y_aux[j], label=f"Gaussian μ={np.round(centers[j,feature],2)}, σ={np.round(sigmas[j,feature],2)}")

plt.title("Projection of the membership functions on Feature 2")
plt.xlabel("Feature 1")
plt.ylabel("Degree of Membership")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ---------------------------
" Gaussian Membership Function "
# ---------------------------
class GaussianMF(nn.Module):
    def __init__(self, centers, sigmas, agg_prob):
        super().__init__()
        self.centers = nn.Parameter(torch.tensor(centers, dtype=torch.float32))
        self.sigmas = nn.Parameter(torch.tensor(sigmas, dtype=torch.float32))
        self.agg_prob=agg_prob

    def forward(self, x):
        # Expand for broadcasting
        # x: (batch, 1, n_dims), centers: (1, n_rules, n_dims), sigmas: (1, n_rules, n_dims)
        diff = abs((x.unsqueeze(1) - self.centers.unsqueeze(0))/self.sigmas.unsqueeze(0)) #(batch, n_rules, n_dims)

        # Aggregation
        if self.agg_prob:
            dist = torch.norm(diff, dim=-1)  # (batch, n_rules) # probablistic intersection
        else:
            dist = torch.max(diff, dim=-1).values  # (batch, n_rules) # min intersection (min instersection of normal funtion is the same as the max on dist)
        
        return torch.exp(-0.5 * dist ** 2)

# %%
# ---------------------------
" TSK Model "
# ---------------------------
class TSK(nn.Module):
    def __init__(self, n_inputs, n_rules, centers, sigmas,agg_prob=False):
        super().__init__()
        self.n_inputs = n_inputs
        self.n_rules = n_rules

        # Antecedents (Gaussian MFs)
        
        self.mfs=GaussianMF(centers, sigmas,agg_prob) 

        # Consequents (linear functions of inputs)
        # Each rule has coeffs for each input + bias
        self.consequents = nn.Parameter(
            torch.randn(n_inputs + 1,n_rules)
        )

    def forward(self, x):
        # x: (batch, n_inputs)
        batch_size = x.shape[0]
        
        # Compute membership values for each input feature
        # firing_strengths: (batch, n_rules)
        firing_strengths = self.mfs(x)
        
        # Normalize memberships
        # norm_fs: (batch, n_rules)
        norm_fs = firing_strengths / (firing_strengths.sum(dim=1, keepdim=True) + 1e-9)

        # Consequent output (linear model per rule)
        x_aug = torch.cat([x, torch.ones(batch_size, 1)], dim=1)  # add bias

        rule_outputs = torch.einsum("br,rk->bk", x_aug, self.consequents)  # (batch, rules)
        # Weighted sum
        output = torch.sum(norm_fs * rule_outputs, dim=1, keepdim=True)

        return output, norm_fs, rule_outputs

# %%
# ---------------------------
" Least Squares Solver for Consequents (TSK) "
# ---------------------------
def train_ls(model, X, y):
    with torch.no_grad():
        _, norm_fs, _ = model(X)

        # Design matrix for LS: combine normalized firing strengths with input
        X_aug = torch.cat([X, torch.ones(X.shape[0], 1)], dim=1)
        
        Phi = torch.einsum("br,bi->bri", X_aug, norm_fs).reshape(X.shape[0], -1)
        
        # Solve LS: consequents = (Phi^T Phi)^-1 Phi^T y
        
        theta= torch.linalg.lstsq(Phi, y).solution
    
        
        model.consequents.data = theta.reshape(model.consequents.shape)

# %%
# ---------------------------
" Gradient Descent Training "
# ---------------------------
def train_gd(model, X, y, epochs=100, lr=1e-3):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    for _ in range(epochs):
        optimizer.zero_grad()
        y_pred, _, _ = model(X)
        loss = criterion(y_pred, y)
        print(loss)
        loss.backward()
        optimizer.step()

# %%
# ---------------------------
" Hybrid Training (Classic ANFIS) "
# ---------------------------
def train_hybrid_anfis(model, X, y, max_iters=10, gd_epochs=20, lr=1e-3):
    train_ls(model, X, y)
    for _ in range(max_iters):
        # Step A: GD on antecedents (freeze consequents)
        model.consequents.requires_grad = False
        train_gd(model, X, y, epochs=gd_epochs, lr=lr)

        # Step B: LS on consequents (freeze antecedents)
        model.consequents.requires_grad = True
        model.mfs.requires_grad = False
        train_ls(model, X, y)

        # Re-enable antecedents
        model.mfs.requires_grad = True

# %% [markdown]
# This cell defines the ANFIS algorithm and it uses the Least Squares (for computing the optimal consequents) and the Gradient Descent (for updating membership functions) training functions.
#
# The inputs for this function are:
#
# model – TSK model that contains MFs (membership function parameters, i.e., antecedents) and consequents (linear coefficients in the rules)
#
# X – The input data (features)
#
# y – The target outputs
#
# max_iters – How many times the hybrid process (GD + LS) is repeated
#
# gd_epochs – Number of gradient descent steps per iteration
#
# lr – Learning rate for the gradient descent step

# %%
# ---------------------------
" Alternative Hybrid Training (LS+ gradient descent on all)"
# ---------------------------
def train_hybrid(model, X, y, epochs=100, lr=1e-4):
    # Step 1: LS for consequents
    train_ls(model, X, y)
    # Step 2: GD fine-tuning
    train_gd(model, X, y, epochs=epochs, lr=lr)

# %% [markdown]
# This cell defines an alternative ANFIS training approach where the model is trained in two steps: first, the consequents are computed using Least Squares (LS), and then the entire model (both antecedents and consequents) is fine-tuned using Gradient Descent (GD).
#
# The inputs for this function are:
#
# model – TSK model that contains MFs (membership function parameters, i.e., antecedents) and consequents (linear coefficients in the rules)
#
# X – The input data (features)
#
# y – The target outputs
#
# epochs – Number of gradient descent steps for fine-tuning
#
# lr – Learning rate for the gradient descent step

# %%
"Build TSK model for regression"

#create TSK model using input size, number of rules, centers and sigmas from clustering
model = TSK(
    n_inputs=Xtr.shape[1],  #number of features
    n_rules=n_clusters,     #number of fuzzy rules
    centers=centers[:,:-1], #ignore target dimension for antecedents
    sigmas=sigmas[:,:-1])

#convert datasets to PyTorch tensors
Xtr = torch.tensor(Xtr, dtype=torch.float32)
ytr = torch.tensor(ytr, dtype=torch.float32)
Xte = torch.tensor(Xte, dtype=torch.float32)
yte = torch.tensor(yte, dtype=torch.float32)

# %%
"Training with hybrid ANFIS"
    
train_hybrid_anfis(model, Xtr, ytr.reshape(-1,1), max_iters = 20, gd_epochs = 20, lr = 1e-3)
# Out:
# tensor(2683.3911, grad_fn=<MseLossBackward0>)
# tensor(2682.0906, grad_fn=<MseLossBackward0>)
# tensor(2680.8708, grad_fn=<MseLossBackward0>)
# tensor(2679.6748, grad_fn=<MseLossBackward0>)
# tensor(2678.5159, grad_fn=<MseLossBackward0>)
# tensor(2677.4026, grad_fn=<MseLossBackward0>)
# tensor(2676.3201, grad_fn=<MseLossBackward0>)
# tensor(2675.2358, grad_fn=<MseLossBackward0>)
# tensor(2674.1296, grad_fn=<MseLossBackward0>)
# tensor(2673.0330, grad_fn=<MseLossBackward0>)
# tensor(2671.9392, grad_fn=<MseLossBackward0>)
# tensor(2670.8506, grad_fn=<MseLossBackward0>)
# tensor(2669.7742, grad_fn=<MseLossBackward0>)
# tensor(2668.6841, grad_fn=<MseLossBackward0>)
# tensor(2667.5979, grad_fn=<MseLossBackward0>)
# tensor(2666.5088, grad_fn=<MseLossBackward0>)
# tensor(2665.4280, grad_fn=<MseLossBackward0>)
# tensor(2664.3716, grad_fn=<MseLossBackward0>)
# tensor(2663.3245, grad_fn=<MseLossBackward0>)
# tensor(2662.2820, grad_fn=<MseLossBackward0>)
# tensor(2658.7915, grad_fn=<MseLossBackward0>)
# tensor(2657.5164, grad_fn=<MseLossBackward0>)
# tensor(2656.2993, grad_fn=<MseLossBackward0>)
# tensor(2655.0771, grad_fn=<MseLossBackward0>)
# tensor(2653.8906, grad_fn=<MseLossBackward0>)
# tensor(2652.7100, grad_fn=<MseLossBackward0>)
# tensor(2651.5442, grad_fn=<MseLossBackward0>)
# tensor(2650.3892, grad_fn=<MseLossBackward0>)
# tensor(2649.2485, grad_fn=<MseLossBackward0>)
# tensor(2648.1077, grad_fn=<MseLossBackward0>)
# tensor(2646.9778, grad_fn=<MseLossBackward0>)
# tensor(2645.8662, grad_fn=<MseLossBackward0>)
# tensor(2644.7556, grad_fn=<MseLossBackward0>)
# tensor(2643.6492, grad_fn=<MseLossBackward0>)
# tensor(2642.5557, grad_fn=<MseLossBackward0>)
# tensor(2641.4802, grad_fn=<MseLossBackward0>)
# tensor(2640.3955, grad_fn=<MseLossBackward0>)
# tensor(2639.3171, grad_fn=<MseLossBackward0>)
# tensor(2638.2483, grad_fn=<MseLossBackward0>)
# tensor(2637.1809, grad_fn=<MseLossBackward0>)
# tensor(2633.4795, grad_fn=<MseLossBackward0>)
# tensor(2632.0750, grad_fn=<MseLossBackward0>)
# tensor(2630.6846, grad_fn=<MseLossBackward0>)
# tensor(2629.3015, grad_fn=<MseLossBackward0>)
# tensor(2627.8396, grad_fn=<MseLossBackward0>)
# tensor(2626.3240, grad_fn=<MseLossBackward0>)
# tensor(2624.8176, grad_fn=<MseLossBackward0>)
# tensor(2623.3164, grad_fn=<MseLossBackward0>)
# tensor(2621.8198, grad_fn=<MseLossBackward0>)
# tensor(2620.3584, grad_fn=<MseLossBackward0>)
# tensor(2618.9106, grad_fn=<MseLossBackward0>)
# tensor(2617.4749, grad_fn=<MseLossBackward0>)
# tensor(2616.0557, grad_fn=<MseLossBackward0>)
# tensor(2614.6680, grad_fn=<MseLossBackward0>)
# tensor(2613.3142, grad_fn=<MseLossBackward0>)
# tensor(2611.9756, grad_fn=<MseLossBackward0>)
# tensor(2610.6594, grad_fn=<MseLossBackward0>)
# tensor(2609.3784, grad_fn=<MseLossBackward0>)
# tensor(2608.1130, grad_fn=<MseLossBackward0>)
# tensor(2606.8521, grad_fn=<MseLossBackward0>)
# tensor(2601.2358, grad_fn=<MseLossBackward0>)
# tensor(2599.5132, grad_fn=<MseLossBackward0>)
# tensor(2597.8560, grad_fn=<MseLossBackward0>)
# tensor(2596.2278, grad_fn=<MseLossBackward0>)
# tensor(2594.6279, grad_fn=<MseLossBackward0>)
# tensor(2593.0503, grad_fn=<MseLossBackward0>)
# tensor(2591.4976, grad_fn=<MseLossBackward0>)
# tensor(2589.9714, grad_fn=<MseLossBackward0>)
# tensor(2588.4846, grad_fn=<MseLossBackward0>)
# tensor(2587.0486, grad_fn=<MseLossBackward0>)
# tensor(2585.6362, grad_fn=<MseLossBackward0>)
# tensor(2584.2749, grad_fn=<MseLossBackward0>)
# tensor(2582.9277, grad_fn=<MseLossBackward0>)
# tensor(2581.6252, grad_fn=<MseLossBackward0>)
# tensor(2580.3591, grad_fn=<MseLossBackward0>)
# tensor(2579.1326, grad_fn=<MseLossBackward0>)
# tensor(2577.9470, grad_fn=<MseLossBackward0>)
# tensor(2576.7991, grad_fn=<MseLossBackward0>)
# tensor(2575.7109, grad_fn=<MseLossBackward0>)
# tensor(2574.6106, grad_fn=<MseLossBackward0>)
# tensor(2568.5776, grad_fn=<MseLossBackward0>)
# tensor(2567.0623, grad_fn=<MseLossBackward0>)
# tensor(2565.6089, grad_fn=<MseLossBackward0>)
# tensor(2564.2380, grad_fn=<MseLossBackward0>)
# tensor(2562.9004, grad_fn=<MseLossBackward0>)
# tensor(2561.6057, grad_fn=<MseLossBackward0>)
# tensor(2560.3599, grad_fn=<MseLossBackward0>)
# tensor(2559.1458, grad_fn=<MseLossBackward0>)
# tensor(2557.9385, grad_fn=<MseLossBackward0>)
# tensor(2556.7754, grad_fn=<MseLossBackward0>)
# tensor(2555.6541, grad_fn=<MseLossBackward0>)
# tensor(2554.5112, grad_fn=<MseLossBackward0>)
# tensor(2553.3923, grad_fn=<MseLossBackward0>)
# tensor(2552.3035, grad_fn=<MseLossBackward0>)
# tensor(2551.2407, grad_fn=<MseLossBackward0>)
# tensor(2550.2007, grad_fn=<MseLossBackward0>)
# tensor(2549.1628, grad_fn=<MseLossBackward0>)
# tensor(2548.1194, grad_fn=<MseLossBackward0>)
# tensor(2547.0657, grad_fn=<MseLossBackward0>)
# tensor(2546.0112, grad_fn=<MseLossBackward0>)
# tensor(2541.4312, grad_fn=<MseLossBackward0>)
# tensor(2539.9790, grad_fn=<MseLossBackward0>)
# tensor(2538.6016, grad_fn=<MseLossBackward0>)
# tensor(2537.2935, grad_fn=<MseLossBackward0>)
# tensor(2536.0427, grad_fn=<MseLossBackward0>)
# tensor(2534.8481, grad_fn=<MseLossBackward0>)
# tensor(2533.7188, grad_fn=<MseLossBackward0>)
# tensor(2532.5662, grad_fn=<MseLossBackward0>)
# tensor(2531.4128, grad_fn=<MseLossBackward0>)
# tensor(2530.2805, grad_fn=<MseLossBackward0>)
# tensor(2529.1594, grad_fn=<MseLossBackward0>)
# tensor(2528.0378, grad_fn=<MseLossBackward0>)
# tensor(2526.9023, grad_fn=<MseLossBackward0>)
# tensor(2525.7959, grad_fn=<MseLossBackward0>)
# tensor(2524.7097, grad_fn=<MseLossBackward0>)
# tensor(2523.7297, grad_fn=<MseLossBackward0>)
# tensor(2522.7585, grad_fn=<MseLossBackward0>)
# tensor(2521.7927, grad_fn=<MseLossBackward0>)
# tensor(2520.8293, grad_fn=<MseLossBackward0>)
# tensor(2519.8708, grad_fn=<MseLossBackward0>)
# tensor(2514.7661, grad_fn=<MseLossBackward0>)
# tensor(2512.6831, grad_fn=<MseLossBackward0>)
# tensor(2510.7820, grad_fn=<MseLossBackward0>)
# tensor(2509.0093, grad_fn=<MseLossBackward0>)
# tensor(2507.3599, grad_fn=<MseLossBackward0>)
# tensor(2505.7632, grad_fn=<MseLossBackward0>)
# tensor(2504.2124, grad_fn=<MseLossBackward0>)
# tensor(2502.7124, grad_fn=<MseLossBackward0>)
# tensor(2501.2664, grad_fn=<MseLossBackward0>)
# tensor(2499.8479, grad_fn=<MseLossBackward0>)
# tensor(2498.4451, grad_fn=<MseLossBackward0>)
# tensor(2497.0823, grad_fn=<MseLossBackward0>)
# tensor(2495.9690, grad_fn=<MseLossBackward0>)
# tensor(2495.0269, grad_fn=<MseLossBackward0>)
# tensor(2494.0867, grad_fn=<MseLossBackward0>)
# tensor(2493.1472, grad_fn=<MseLossBackward0>)
# tensor(2492.2178, grad_fn=<MseLossBackward0>)
# tensor(2491.3672, grad_fn=<MseLossBackward0>)
# tensor(2490.4858, grad_fn=<MseLossBackward0>)
# tensor(2489.5889, grad_fn=<MseLossBackward0>)
# tensor(2483.6951, grad_fn=<MseLossBackward0>)
# tensor(2482.1362, grad_fn=<MseLossBackward0>)
# tensor(2480.7063, grad_fn=<MseLossBackward0>)
# tensor(2479.3789, grad_fn=<MseLossBackward0>)
# tensor(2478.3032, grad_fn=<MseLossBackward0>)
# tensor(2477.3469, grad_fn=<MseLossBackward0>)
# tensor(2476.4136, grad_fn=<MseLossBackward0>)
# tensor(2475.4963, grad_fn=<MseLossBackward0>)
# tensor(2474.5947, grad_fn=<MseLossBackward0>)
# tensor(2473.7146, grad_fn=<MseLossBackward0>)
# tensor(2472.7832, grad_fn=<MseLossBackward0>)
# tensor(2471.8691, grad_fn=<MseLossBackward0>)
# tensor(2470.9299, grad_fn=<MseLossBackward0>)
# tensor(2470.0803, grad_fn=<MseLossBackward0>)
# tensor(2469.2485, grad_fn=<MseLossBackward0>)
# tensor(2468.3955, grad_fn=<MseLossBackward0>)
# tensor(2467.5417, grad_fn=<MseLossBackward0>)
# tensor(2466.7324, grad_fn=<MseLossBackward0>)
# tensor(2465.9707, grad_fn=<MseLossBackward0>)
# tensor(2465.1936, grad_fn=<MseLossBackward0>)
# tensor(2462.2017, grad_fn=<MseLossBackward0>)
# tensor(2461.0078, grad_fn=<MseLossBackward0>)
# tensor(2459.9084, grad_fn=<MseLossBackward0>)
# tensor(2459.0098, grad_fn=<MseLossBackward0>)
# tensor(2458.0554, grad_fn=<MseLossBackward0>)
# tensor(2457.2539, grad_fn=<MseLossBackward0>)
# tensor(2456.4326, grad_fn=<MseLossBackward0>)
# tensor(2455.5835, grad_fn=<MseLossBackward0>)
# tensor(2454.7361, grad_fn=<MseLossBackward0>)
# tensor(2453.9119, grad_fn=<MseLossBackward0>)
# tensor(2453.0461, grad_fn=<MseLossBackward0>)
# tensor(2452.1694, grad_fn=<MseLossBackward0>)
# tensor(2451.2610, grad_fn=<MseLossBackward0>)
# tensor(2450.3284, grad_fn=<MseLossBackward0>)
# tensor(2449.3704, grad_fn=<MseLossBackward0>)
# tensor(2448.4268, grad_fn=<MseLossBackward0>)
# tensor(2447.4897, grad_fn=<MseLossBackward0>)
# tensor(2446.5276, grad_fn=<MseLossBackward0>)
# tensor(2445.5740, grad_fn=<MseLossBackward0>)
# tensor(2444.7048, grad_fn=<MseLossBackward0>)
# tensor(2442.6982, grad_fn=<MseLossBackward0>)
# tensor(2441.6704, grad_fn=<MseLossBackward0>)
# tensor(2440.4570, grad_fn=<MseLossBackward0>)
# tensor(2439.2537, grad_fn=<MseLossBackward0>)
# tensor(2438.1997, grad_fn=<MseLossBackward0>)
# tensor(2437.1118, grad_fn=<MseLossBackward0>)
# tensor(2435.9885, grad_fn=<MseLossBackward0>)
# tensor(2434.8044, grad_fn=<MseLossBackward0>)
# tensor(2433.6362, grad_fn=<MseLossBackward0>)
# tensor(2432.4863, grad_fn=<MseLossBackward0>)
# tensor(2431.3643, grad_fn=<MseLossBackward0>)
# tensor(2430.2424, grad_fn=<MseLossBackward0>)
# tensor(2429.1382, grad_fn=<MseLossBackward0>)
# tensor(2428.3098, grad_fn=<MseLossBackward0>)
# tensor(2427.5393, grad_fn=<MseLossBackward0>)
# tensor(2426.7136, grad_fn=<MseLossBackward0>)
# tensor(2425.9250, grad_fn=<MseLossBackward0>)
# tensor(2425.1025, grad_fn=<MseLossBackward0>)
# tensor(2424.2493, grad_fn=<MseLossBackward0>)
# tensor(2423.4167, grad_fn=<MseLossBackward0>)
# tensor(2420.4922, grad_fn=<MseLossBackward0>)
# tensor(2419.0037, grad_fn=<MseLossBackward0>)
# tensor(2417.6982, grad_fn=<MseLossBackward0>)
# tensor(2416.5391, grad_fn=<MseLossBackward0>)
# tensor(2415.4307, grad_fn=<MseLossBackward0>)
# tensor(2414.3296, grad_fn=<MseLossBackward0>)
# tensor(2413.2690, grad_fn=<MseLossBackward0>)
# tensor(2412.2422, grad_fn=<MseLossBackward0>)
# tensor(2411.2661, grad_fn=<MseLossBackward0>)
# tensor(2410.5901, grad_fn=<MseLossBackward0>)
# tensor(2409.8071, grad_fn=<MseLossBackward0>)
# tensor(2408.8694, grad_fn=<MseLossBackward0>)
# tensor(2408.0874, grad_fn=<MseLossBackward0>)
# tensor(2407.4346, grad_fn=<MseLossBackward0>)
# tensor(2406.8601, grad_fn=<MseLossBackward0>)
# tensor(2406.3601, grad_fn=<MseLossBackward0>)
# tensor(2405.8179, grad_fn=<MseLossBackward0>)
# tensor(2405.2727, grad_fn=<MseLossBackward0>)
# tensor(2404.7800, grad_fn=<MseLossBackward0>)
# tensor(2404.3315, grad_fn=<MseLossBackward0>)
# tensor(2399.6648, grad_fn=<MseLossBackward0>)
# tensor(2398.5967, grad_fn=<MseLossBackward0>)
# tensor(2397.8379, grad_fn=<MseLossBackward0>)
# tensor(2397.2432, grad_fn=<MseLossBackward0>)
# tensor(2396.6802, grad_fn=<MseLossBackward0>)
# tensor(2396.1428, grad_fn=<MseLossBackward0>)
# tensor(2395.6545, grad_fn=<MseLossBackward0>)
# tensor(2395.1509, grad_fn=<MseLossBackward0>)
# tensor(2394.6440, grad_fn=<MseLossBackward0>)
# tensor(2394.1831, grad_fn=<MseLossBackward0>)
# tensor(2393.7986, grad_fn=<MseLossBackward0>)
# tensor(2393.4297, grad_fn=<MseLossBackward0>)
# tensor(2393.0117, grad_fn=<MseLossBackward0>)
# tensor(2392.7131, grad_fn=<MseLossBackward0>)
# tensor(2392.2527, grad_fn=<MseLossBackward0>)
# tensor(2391.9163, grad_fn=<MseLossBackward0>)
# tensor(2391.5500, grad_fn=<MseLossBackward0>)
# tensor(2391.1729, grad_fn=<MseLossBackward0>)
# tensor(2390.7800, grad_fn=<MseLossBackward0>)
# tensor(2390.3613, grad_fn=<MseLossBackward0>)
# tensor(2388.7825, grad_fn=<MseLossBackward0>)
# tensor(2388.3831, grad_fn=<MseLossBackward0>)
# tensor(2387.9292, grad_fn=<MseLossBackward0>)
# tensor(2387.3606, grad_fn=<MseLossBackward0>)
# tensor(2387.0056, grad_fn=<MseLossBackward0>)
# tensor(2386.6138, grad_fn=<MseLossBackward0>)
# tensor(2386.2148, grad_fn=<MseLossBackward0>)
# tensor(2385.7812, grad_fn=<MseLossBackward0>)
# tensor(2385.3633, grad_fn=<MseLossBackward0>)
# tensor(2384.9143, grad_fn=<MseLossBackward0>)
# tensor(2384.5439, grad_fn=<MseLossBackward0>)
# tensor(2384.1699, grad_fn=<MseLossBackward0>)
# tensor(2383.7947, grad_fn=<MseLossBackward0>)
# tensor(2383.3887, grad_fn=<MseLossBackward0>)
# tensor(2383.0103, grad_fn=<MseLossBackward0>)
# tensor(2382.6277, grad_fn=<MseLossBackward0>)
# tensor(2382.2585, grad_fn=<MseLossBackward0>)
# tensor(2381.8862, grad_fn=<MseLossBackward0>)
# tensor(2381.5027, grad_fn=<MseLossBackward0>)
# tensor(2381.1157, grad_fn=<MseLossBackward0>)
# tensor(2380.1846, grad_fn=<MseLossBackward0>)
# tensor(2379.9224, grad_fn=<MseLossBackward0>)
# tensor(2379.5103, grad_fn=<MseLossBackward0>)
# tensor(2379.5068, grad_fn=<MseLossBackward0>)
# tensor(2378.7712, grad_fn=<MseLossBackward0>)
# tensor(2378.2805, grad_fn=<MseLossBackward0>)
# tensor(2377.9238, grad_fn=<MseLossBackward0>)
# tensor(2377.5796, grad_fn=<MseLossBackward0>)
# tensor(2377.2605, grad_fn=<MseLossBackward0>)
# tensor(2376.8965, grad_fn=<MseLossBackward0>)
# tensor(2376.5059, grad_fn=<MseLossBackward0>)
# tensor(2376.2554, grad_fn=<MseLossBackward0>)
# tensor(2376.0469, grad_fn=<MseLossBackward0>)
# tensor(2375.6755, grad_fn=<MseLossBackward0>)
# tensor(2375.2939, grad_fn=<MseLossBackward0>)
# tensor(2374.9402, grad_fn=<MseLossBackward0>)
# tensor(2374.6909, grad_fn=<MseLossBackward0>)
# tensor(2374.4192, grad_fn=<MseLossBackward0>)
# tensor(2374.1130, grad_fn=<MseLossBackward0>)
# tensor(2373.7888, grad_fn=<MseLossBackward0>)
# tensor(2372.9773, grad_fn=<MseLossBackward0>)
# tensor(2372.8853, grad_fn=<MseLossBackward0>)
# tensor(2372.4749, grad_fn=<MseLossBackward0>)
# tensor(2371.9424, grad_fn=<MseLossBackward0>)
# tensor(2371.6128, grad_fn=<MseLossBackward0>)
# tensor(2371.5769, grad_fn=<MseLossBackward0>)
# tensor(2370.9746, grad_fn=<MseLossBackward0>)
# tensor(2370.6775, grad_fn=<MseLossBackward0>)
# tensor(2370.4258, grad_fn=<MseLossBackward0>)
# tensor(2370.1626, grad_fn=<MseLossBackward0>)
# tensor(2369.8516, grad_fn=<MseLossBackward0>)
# tensor(2369.5046, grad_fn=<MseLossBackward0>)
# tensor(2369.1436, grad_fn=<MseLossBackward0>)
# tensor(2368.8662, grad_fn=<MseLossBackward0>)
# tensor(2368.5964, grad_fn=<MseLossBackward0>)
# tensor(2368.3003, grad_fn=<MseLossBackward0>)
# tensor(2367.9751, grad_fn=<MseLossBackward0>)
# tensor(2367.6543, grad_fn=<MseLossBackward0>)
# tensor(2367.3804, grad_fn=<MseLossBackward0>)
# tensor(2367.1421, grad_fn=<MseLossBackward0>)
# tensor(2366.5959, grad_fn=<MseLossBackward0>)
# tensor(2366.4624, grad_fn=<MseLossBackward0>)
# tensor(2366.0784, grad_fn=<MseLossBackward0>)
# tensor(2365.7122, grad_fn=<MseLossBackward0>)
# tensor(2365.4072, grad_fn=<MseLossBackward0>)
# tensor(2365.1912, grad_fn=<MseLossBackward0>)
# tensor(2364.9268, grad_fn=<MseLossBackward0>)
# tensor(2364.6406, grad_fn=<MseLossBackward0>)
# tensor(2364.3552, grad_fn=<MseLossBackward0>)
# tensor(2363.9797, grad_fn=<MseLossBackward0>)
# tensor(2363.6873, grad_fn=<MseLossBackward0>)
# tensor(2363.3872, grad_fn=<MseLossBackward0>)
# tensor(2363.1111, grad_fn=<MseLossBackward0>)
# tensor(2362.8535, grad_fn=<MseLossBackward0>)
# tensor(2362.5730, grad_fn=<MseLossBackward0>)
# tensor(2362.2754, grad_fn=<MseLossBackward0>)
# tensor(2361.9663, grad_fn=<MseLossBackward0>)
# tensor(2361.6514, grad_fn=<MseLossBackward0>)
# tensor(2361.4351, grad_fn=<MseLossBackward0>)
# tensor(2361.1826, grad_fn=<MseLossBackward0>)
# tensor(2360.6460, grad_fn=<MseLossBackward0>)
# tensor(2360.6079, grad_fn=<MseLossBackward0>)
# tensor(2360.0962, grad_fn=<MseLossBackward0>)
# tensor(2359.7075, grad_fn=<MseLossBackward0>)
# tensor(2359.4915, grad_fn=<MseLossBackward0>)
# tensor(2359.2681, grad_fn=<MseLossBackward0>)
# tensor(2359.0486, grad_fn=<MseLossBackward0>)
# tensor(2358.7781, grad_fn=<MseLossBackward0>)
# tensor(2358.5615, grad_fn=<MseLossBackward0>)
# tensor(2358.3994, grad_fn=<MseLossBackward0>)
# tensor(2358.1667, grad_fn=<MseLossBackward0>)
# tensor(2357.8965, grad_fn=<MseLossBackward0>)
# tensor(2357.6101, grad_fn=<MseLossBackward0>)
# tensor(2357.3567, grad_fn=<MseLossBackward0>)
# tensor(2357.1326, grad_fn=<MseLossBackward0>)
# tensor(2356.9399, grad_fn=<MseLossBackward0>)
# tensor(2356.7334, grad_fn=<MseLossBackward0>)
# tensor(2356.5015, grad_fn=<MseLossBackward0>)
# tensor(2356.2527, grad_fn=<MseLossBackward0>)
# tensor(2356.0645, grad_fn=<MseLossBackward0>)
# tensor(2355.5686, grad_fn=<MseLossBackward0>)
# tensor(2356.0151, grad_fn=<MseLossBackward0>)
# tensor(2355.1990, grad_fn=<MseLossBackward0>)
# tensor(2354.9731, grad_fn=<MseLossBackward0>)
# tensor(2354.9021, grad_fn=<MseLossBackward0>)
# tensor(2354.7937, grad_fn=<MseLossBackward0>)
# tensor(2354.6074, grad_fn=<MseLossBackward0>)
# tensor(2354.3779, grad_fn=<MseLossBackward0>)
# tensor(2354.1335, grad_fn=<MseLossBackward0>)
# tensor(2353.9180, grad_fn=<MseLossBackward0>)
# tensor(2353.6704, grad_fn=<MseLossBackward0>)
# tensor(2353.4158, grad_fn=<MseLossBackward0>)
# tensor(2353.2197, grad_fn=<MseLossBackward0>)
# tensor(2353.0078, grad_fn=<MseLossBackward0>)
# tensor(2352.8066, grad_fn=<MseLossBackward0>)
# tensor(2352.5728, grad_fn=<MseLossBackward0>)
# tensor(2352.3721, grad_fn=<MseLossBackward0>)
# tensor(2352.2039, grad_fn=<MseLossBackward0>)
# tensor(2352.0188, grad_fn=<MseLossBackward0>)
# tensor(2351.8098, grad_fn=<MseLossBackward0>)
# tensor(2351.4253, grad_fn=<MseLossBackward0>)
# tensor(2351.3474, grad_fn=<MseLossBackward0>)
# tensor(2350.9670, grad_fn=<MseLossBackward0>)
# tensor(2350.8591, grad_fn=<MseLossBackward0>)
# tensor(2350.6204, grad_fn=<MseLossBackward0>)
# tensor(2350.4810, grad_fn=<MseLossBackward0>)
# tensor(2350.2856, grad_fn=<MseLossBackward0>)
# tensor(2350.1326, grad_fn=<MseLossBackward0>)
# tensor(2349.8782, grad_fn=<MseLossBackward0>)
# tensor(2349.5889, grad_fn=<MseLossBackward0>)
# tensor(2349.3398, grad_fn=<MseLossBackward0>)
# tensor(2349.1833, grad_fn=<MseLossBackward0>)
# tensor(2349.0298, grad_fn=<MseLossBackward0>)
# tensor(2348.8499, grad_fn=<MseLossBackward0>)
# tensor(2348.6084, grad_fn=<MseLossBackward0>)
# tensor(2348.3525, grad_fn=<MseLossBackward0>)
# tensor(2348.1602, grad_fn=<MseLossBackward0>)
# tensor(2348.0029, grad_fn=<MseLossBackward0>)
# tensor(2347.8464, grad_fn=<MseLossBackward0>)
# tensor(2347.6377, grad_fn=<MseLossBackward0>)
# tensor(2347.3025, grad_fn=<MseLossBackward0>)
# tensor(2347.9365, grad_fn=<MseLossBackward0>)
# tensor(2347.1377, grad_fn=<MseLossBackward0>)
# tensor(2346.9248, grad_fn=<MseLossBackward0>)
# tensor(2346.9707, grad_fn=<MseLossBackward0>)
# tensor(2346.8430, grad_fn=<MseLossBackward0>)
# tensor(2346.6890, grad_fn=<MseLossBackward0>)
# tensor(2346.5464, grad_fn=<MseLossBackward0>)
# tensor(2346.3208, grad_fn=<MseLossBackward0>)
# tensor(2346.1650, grad_fn=<MseLossBackward0>)
# tensor(2345.9780, grad_fn=<MseLossBackward0>)
# tensor(2345.8516, grad_fn=<MseLossBackward0>)
# tensor(2345.6453, grad_fn=<MseLossBackward0>)
# tensor(2345.5273, grad_fn=<MseLossBackward0>)
# tensor(2345.3887, grad_fn=<MseLossBackward0>)
# tensor(2345.2302, grad_fn=<MseLossBackward0>)
# tensor(2345.0500, grad_fn=<MseLossBackward0>)
# tensor(2344.9268, grad_fn=<MseLossBackward0>)
# tensor(2344.7893, grad_fn=<MseLossBackward0>)
# tensor(2344.6384, grad_fn=<MseLossBackward0>)

# %% [markdown]
# This time the training is done with ANFIS.

# %%
y_pred, _, _=model(Xte)

# %%
"Performance metrics: Accuracy for classification problem and MSE for regression"

if task == "b":
    print(f'ACC:{accuracy_score(yte.detach().numpy(),y_pred.detach().numpy()>0.5)}') #classification
elif task == "r":
    print(f'MSE:{mean_squared_error(yte.detach().numpy(),y_pred.detach().numpy())}') #regression
else:
    sys.exit()
# Out:
# MSE:2769.499267578125
